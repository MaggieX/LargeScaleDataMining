# %% [markdown]
# # Introduction

# %% [markdown]
# Clustering algorithms are unsupervised methods for finding groups of data points that have similar representations in a feature space. Clustering differs from classification in that no a priori labeling (grouping) of the data points is available.
# K-means clustering is a simple and popular clustering algorithm. Given a set of points in multifimentional space, it tries to find K clusters such that each data point belongs to exactly one cluster, and that the sum of the squares of the distances between each data point and the center of the cluster it belongs to is minimized.

# %% [markdown]
# Approach of K-means algorithm is to repeatedly perform the following two steps until convergence:
# 1. (Re)assign each data point to the cluster whose center is nearest to the data point.
# 2. (Re)calculate the position of the centers of the clusters: setting the center of the cluster to the mean of the data points that are currently within the cluster.

# %% [markdown]
# The center positions may be initialized randomly.

# %% [markdown]
# In the project, we have the following goals:
# 1. Find proper representations of the data, s.t. the clustering is efficient and gives out reasonable results.
# 2. Perform K-means clustering on the dataset, and evaluate the result of the clustering.
# 3. Try different preprocessing methods which may increase the performance of the clustering.

# %% [markdown]
# ## Dataset

# %% [markdown]
# We work with "20 Newsgroups" dataset. It is a collection of approximately 20,000 documents, partitioned (nearly) evenly across 20 different newsgroups, each corresponding to a different category (topic). Each topic can be viewed as a "class".<br>
# In order to define the clustering task, we pretend as if the class labels are not available and aim to find groupings of the documents, where documents in each group are more similar to each other than to those in other groups. We then use class labels as the group truth to evaluate the performance of the clustering task.<br>
# To get started with a simple clustering task, we work with a well-separable portion of the data set, and see if we can retrieve the known classes.

# %% [markdown]
# # Part 1 - Clustering of Text Data

# %%
import numpy as np 
np.random.seed(42) 
import random
random.seed(42)

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.metrics.cluster import contingency_matrix

from sklearn.metrics import homogeneity_score
from sklearn.metrics import completeness_score
from sklearn.metrics import v_measure_score
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import adjusted_mutual_info_score

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF

from sklearn.preprocessing import scale

# %%
categories = ['comp.graphics', 'comp.os.ms-windows.misc',
              'comp.sys.ibm.pc.hardware','comp.sys.mac.hardware', 
              'rec.autos', 'rec.motorcycles',
              'rec.sport.baseball', 'rec.sport.hockey']
dataset = fetch_20newsgroups(subset='all', categories=categories, shuffle=True, random_state=42)

#convert the labels to binary!
conv_train_target = [0 if (i in range(0,4)) else 1 for i in dataset.target]

# %%
print(dataset.target)
print(dataset.target_names)
# Out:
# [2 1 2 ... 2 3 4]
# ['comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey']

# %% [markdown]
# ### 1. Building the TF-IDF matrix

# %% [markdown]
# Transform the documents into TF-IDF vectors.
# Use min.df = 3, exclude the stopwords (no need to do stemming or lemmatization.)

# %%
vectorizer = CountVectorizer(min_df=3, stop_words='english')
dataset_vector = vectorizer.fit_transform(dataset.data)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(dataset_vector)
print(X_train_tfidf.shape)
# Out:
# (7882, 27768)

# %%
print(vectorizer.get_feature_names()[5400:5500])
# Out:
# ['believes', 'believing', 'belive', 'bell', 'bellcore', 'belle', 'bellevue', 'belliveau', 'bellnet', 'bellnorthernresearch', 'bellow', 'bellows', 'belly', 'belmonte', 'belong', 'belonged', 'belonging', 'belongs', 'beloved', 'belt', 'belts', 'beltway', 'bemben', 'bemybaby', 'ben', 'benavides', 'bench', 'benched', 'benches', 'benchmark', 'benchmarks', 'bend', 'bending', 'bendtsen', 'beneath', 'beneficial', 'benefit', 'benefits', 'beng', 'benham', 'benign', 'benjamin', 'bennett', 'bennies', 'benning', 'benoit', 'benoit_brunet', 'benoit_hogue', 'bense', 'benson', 'bent', 'benz', 'beowulf', 'beranek', 'bereft', 'beretta', 'berg', 'bergen', 'berger', 'bergeron', 'bergevin', 'bergland', 'bergman', 'bergqvist', 'berkeley', 'berkshire', 'berlin', 'berman', 'bernard', 'bernd', 'berne', 'bernie', 'bernie_nicholls', 'bernoulli', 'bernstein', 'berry', 'berryhill', 'bert', 'berth', 'berthiaume', 'berthold', 'berube', 'beryllium', 'bessette', 'best', 'bestowed', 'bet', 'beta', 'betas', 'beth', 'bethd', 'bethdc5sv80', 'bethesda', 'bets', 'better', 'betting', 'bettman', 'betz', 'beverage', 'beverages']

# %% [markdown]
# ### 2. Apply K-means clustering

# %% [markdown]
# Apply K-means clusteirng with k=2 using the TF-IDF data.

# %%
init_kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=1000, random_state=0)
kmeans = init_kmeans.fit(X_train_tfidf)
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %% [markdown]
# #### 2a. Contingency table A.
# A_ij is the number of data points that belong to both the class C_i and the cluster K_j.

# %%
contingency_matrix(labels_true=conv_train_target, labels_pred=kmeans.labels_, 
                  eps=None, sparse=False)
# Out:
# array([[   4, 3899],
#        [1727, 2252]])

# %% [markdown]
# #### 2b. Scores: homogenity score, completeness score, V-measure, adjusted Rand score, adjusted mutual info score

# %% [markdown]
# In order to evaluate clustering results, we use five measures for a given partition of the data points with respect to the ground truth. (sklearn.metrics)

# %%
def print_measure_scores(labels_true, labels_pred):
    homogeneity = homogeneity_score(labels_true, labels_pred)
    completeness = completeness_score(labels_true, labels_pred)
    v_measure = v_measure_score(labels_true, labels_pred)
    adj_rand = adjusted_rand_score(labels_true, labels_pred)
    adj_mutual = adjusted_mutual_info_score(labels_true, labels_pred)
    print("Homogeneity score: {0}\nCompleteness score: {1}\nV-measure score: {2}\nAdjusted rand score: {3}\nAdjusted mutual info score: {4}\n"
          .format(homogeneity, completeness, v_measure, adj_rand, adj_mutual))

# %%
print_measure_scores(conv_train_target, kmeans.labels_)
# Out:
# Homogeneity score: 0.25524533029125557
# Completeness score: 0.3360642181760738
# V-measure score: 0.29013170035817176
# Adjusted rand score: 0.18270954372564327
# Adjusted mutual info score: 0.2900578196804613

# %%
print(kmeans.labels_.shape)
# Out:
# (7882,)

# %% [markdown]
# As observed, high dimensional TF-IDF vectors do not yield a good clustering result. One of the reasons is that in a high-D space, the Euclidean distance is not a good metric anymore, in the sense that the distances between data points tends to be almost the same. <br>
# K-means clustering has other limitations. Since its objective is to minimize the sum of within-cluster l_2 distances, it implicityly assums that the clusters are isotropically shaped (i.e. round-shaped). When the clusters are not round-shaped, K-means may fail to identify the clusters properly. <br>
# Even when the clusters are round, K-means algorithm may also fail when the clusters have unequal variances.

# %% [markdown]
# ### 3. Dimension Reduction

# %% [markdown]
# In this part, we try to find a "better" representation tailored to the way that K-means clustering algorithm works, by REDUCING the dimension of our data before clustering. We will use Singular Value Decomposition (SVD) and Non-negative matrix factorization (NMF) for dimensionality reduction.<br>
# First, find the effective dimension of the data through inspection of the top singular values of the TF-IDF matrix and see how many of them are significant in reconstructing the matrix with the truncated SVD representation.<br>
# A guideline is to see what ratio of the variance of the original data is RETAINED after the dimensionality reduction.<br>
# Report the plot of the percent of variance the top r principle components can retain v.s. r, for r = 1 to 1000.

# %%
svd = TruncatedSVD(n_components = 1000, algorithm='randomized',n_iter=5, random_state=None,tol=0.0)
svd_reduced = svd.fit_transform(X_train_tfidf)
print(svd.explained_variance_ratio_[:30:1])
# Out:
# [0.00119855 0.00516645 0.00364295 0.003559   0.00320919 0.00255188
#  0.00249447 0.00241068 0.00231247 0.00218292 0.00215683 0.00209896
#  0.00203723 0.00199506 0.00197322 0.00192575 0.00191031 0.00186392
#  0.00184037 0.00180183 0.00177212 0.00171432 0.00168549 0.00166787
#  0.00165617 0.00164475 0.00159955 0.00158992 0.0015745  0.00155278]

# %%
print(svd.explained_variance_ratio_.sum())
print(np.dot(X_train_tfidf.T, X_train_tfidf).diagonal().sum())
# Out:
# 0.5601128681067259
# 7882.0

# %%
print('Reduced SVD shape:', svd_reduced.shape)
# Out:
# Reduced SVD shape: (7882, 1000)

# %%
svd_reduced[:,:1]
# Out:
# array([[0.12491455],
#        [0.11487509],
#        [0.14972207],
#        ...,
#        [0.09497781],
#        [0.14869694],
#        [0.09084749]])

# %%
svd_reduced[:,:3]
# Out:
# array([[ 0.12491455,  0.01779357, -0.01403145],
#        [ 0.11487509,  0.05393205, -0.03519844],
#        [ 0.14972207,  0.13673575,  0.09422607],
#        ...,
#        [ 0.09497781,  0.01605395, -0.0273249 ],
#        [ 0.14869694,  0.01003593, -0.01292828],
#        [ 0.09084749, -0.00094235, -0.00702921]])

# %%
# Sort in ascending order
svd_ascend = np.sort(svd.explained_variance_ratio_)

# Reverse the sorted array
svd_descend = svd_ascend[::-1]

top_r = [0]*1000

for i in range(1000):
    top_r[i] = svd_descend[0:i].sum()

#plot of the percent of variance the top r principle components can retain v.s. r,
x = np.arange(1, 1001)
fig, ax = plt.subplots() #returns a tuple containing a fig and axes object(s)
ax.plot(x, top_r)
ax.set(xlabel='Principle components r', ylabel='Percent of Variance',
      title='Percent of variance of the top r principle components')
fig.savefig("Percent of variance of the top r principle components.png")

# Turn on the minor TICKS
ax.minorticks_on()

#Customize the grids
ax.grid(which='major',linestyle='--', linewidth='0.5', color='red')
ax.grid(which='minor',linestyle=':', linewidth='0.5', color='black')

# %% [markdown]
# Now, use the following two methods to reduce the dimension of the data. Sweep over the dimension parameters for each method, and choose one that yields better results in terms of clustering purity metrics.<br>
# 1. Truncated SVD/PCA: <br>
# Note that one does not need to perform SVD multiple times: performing SVD with r = 1000 gives the data projected on all the top 1000 principle components, so for smaller r's, one just need to exclude the least important features. <br>
# 2. Non-negative matrix factorization (NMF)

# %%
# Plot 5 measurement scores
score = ['Homogeneity', 'Completeness', 'V-measure', 'Adjusted Rand', 'Adjusted Mutual']
def plot_measure_scores(n_components, scores, title):
    fig, ax = plt.subplots()
    for i in range(len(scores)):
        ax.plot(n_components, scores[i], marker = 11, label = score[i])
    ax.set(xlabel='n_components reduction (r)', ylabel ='Measure Scores for SVD', title = title)
    ax.grid()
    ax.legend()

# %%
# Using SVD for dimentionality reduction
n_components = [1, 2, 3, 5, 10, 20, 50, 100, 300]
svd_homo, svd_comp, svd_v_mea, svd_adj_ran, svd_adj_mut = [], [], [], [], [] 
labels_true = conv_train_target
for r in n_components:
    labels_pred = init_kmeans.fit(svd_reduced[:,:r]).labels_
    svd_homo.append(homogeneity_score(labels_true, labels_pred))
    svd_comp.append(completeness_score(labels_true, labels_pred))
    svd_v_mea.append(v_measure_score(labels_true, labels_pred))
    svd_adj_ran.append(adjusted_rand_score(labels_true, labels_pred))
    svd_adj_mut.append(adjusted_mutual_info_score(labels_true, labels_pred))

# %%
# First four dimension values of the principal components (n_components)
plot_measure_scores(n_components[:5], [svd_homo[:5], svd_comp[:5], svd_v_mea[:5], svd_adj_ran[:5], svd_adj_mut[:5]], 'Measure scores for SVD v.s. n-components')

# %%
# Dimensions r belongs to n_components, measure scores v.s. r for SVD
plot_measure_scores(n_components, [svd_homo, svd_comp, svd_v_mea, svd_adj_ran, svd_adj_mut], 'Measure scores for SVD v.s. n-components')

# %% [markdown]
# Non-monotonic behavior of the measures as r increases can be attributed to the following:<br>
# 1.
# 2.

# %%
# For NMF with r = 2 (dimension for reducing data to)
model = NMF(n_components=2, init='random', random_state=0)
W = model.fit_transform(X_train_tfidf)
H = model.components_
print('W:', W, 'W.shape:', W.shape)
print('H:', H, 'H.shape:', H.shape)
# Out:
# W: [[0.00786768 0.01721846]
#  [0.00181358 0.0249825 ]
#  [0.         0.04123792]
#  ...
#  [0.00541551 0.01374694]
#  [0.0112037  0.01732916]
#  [0.00885542 0.00730178]] W.shape: (7882, 2)
# H: [[1.29223445e-01 1.62879018e-01 2.96748150e-03 ... 1.31748117e-04
#   1.16623522e-02 1.03458953e-02]
#  [6.33903731e-02 2.03265944e-02 1.53391637e-03 ... 1.02945580e-02
#   0.00000000e+00 0.00000000e+00]] H.shape: (2, 27768)

# %%
# Using NMF for dimensionality reduction
n_components = [1, 2, 3, 5, 10, 20, 50, 100, 300]
nmf_homo = []
nmf_comp = []
nmf_v_mea = []
nmf_adj_r = []
nmf_adj_m = []

labels_true = conv_train_target
#init_kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=1000, random_state=0)

for r in n_components:
    nmf = NMF(n_components=r)
    X_train_tfidf_reduced_nmf = nmf.fit_transform(X_train_tfidf)
    labels_pred = init_kmeans.fit(X_train_tfidf_reduced_nmf).labels_
    
    nmf_homo.append(homogeneity_score(labels_true, labels_pred))
    nmf_comp.append(completeness_score(labels_true, labels_pred))
    nmf_v_mea.append(v_measure_score(labels_true, labels_pred))
    nmf_adj_r.append(adjusted_rand_score(labels_true, labels_pred))
    nmf_adj_m.append(adjusted_mutual_info_score(labels_true, labels_pred))
nmf_scores = [nmf_homo, nmf_comp, nmf_v_mea, nmf_adj_r, nmf_adj_m]

# %%
# First five dimension values of the principal components (n_components)
plot_measure_scores(n_components[:5], [nmf_scores[0][:5], nmf_scores[1][:5], nmf_scores[2][:5], nmf_scores[3][:5], nmf_scores[4][:5]],
                    'Measure scores for NMF v.s. n-components')

# %%
# Dimensions r belongs to n_components, measure scores v.s. r for NMF
plot_measure_scores(n_components, nmf_scores, 
                    'Measure scores for NMF v.s. n-components')

# %% [markdown]
# ### 4a. Visualization

# %% [markdown]
# We can visualize the clustering results by projecting the dim-reduced data points onto 2-D plane with SVD, and coloring the points according to: <br>
# - Ground truth class label
# - Clustering label

# %%
# Visualize the clustering results
def visualize_kmeans_clustering(input_data, predict_data, center, figure_title):
    plt.figure(figsize = (16, 6))
    
    #Ground truth class label
    plt.subplot(1, 2, 1)
    plt.title("Ground truth class label")
    plt.scatter(input_data[:,0], input_data[:,1], marker='o', c=np.asarray(labels_true))
    
    #Clustering label
    plt.subplot(1, 2, 2)
    plt.title(figure_title)
    plt.scatter(input_data[:,0], input_data[:,1], c=predict_data)
    plt.scatter(center[:,0], center[:,1], c='red', s = 150, alpha = 0.6) # cluster center marked in red, alpha blending value btw 0 & 1
    plt.savefig(figure_title)

# %%
# Pick r = 2 for SVD based on results from Part 3 (highest scores)
input_svd_data = svd_reduced[:,:2]
predict_svd_data = init_kmeans.fit(input_svd_data).labels_
svd_centers = init_kmeans.fit(input_svd_data).cluster_centers_ # ndarray(n_clusters, n_features), cluster center coordinates
print(input_svd_data.shape, predict_svd_data.shape, svd_centers.shape)
visualize_kmeans_clustering(input_svd_data, predict_svd_data, svd_centers, 'Kmeans clustering result using SVD (r = 2) for dimentionality reduction')
# Out:
# (7882, 2) (7882,) (2, 2)

# %%
# 5 measurement scores with Kmeans clustering
print('SVD without scaling:')
print(contingency_matrix(conv_train_target, predict_svd_data, eps=None, sparse=False))
print('Measure scores:')
print_measure_scores(conv_train_target, predict_svd_data)
# Out:
# SVD without scaling:
# [[3726  177]
#  [ 520 3459]]
# Measure scores:
# Homogeneity score: 0.5814909307607379
# Completeness score: 0.58397751630097
# V-measure score: 0.5827315709032068
# Adjusted rand score: 0.6775208075943945
# Adjusted mutual info score: 0.5826932882925123

# %%
input_svd_data
# Out:
# array([[ 0.12491455,  0.01779357],
#        [ 0.11487509,  0.05393205],
#        [ 0.14972207,  0.13673575],
#        ...,
#        [ 0.09497781,  0.01605395],
#        [ 0.14869694,  0.01003593],
#        [ 0.09084749, -0.00094235]])

# %%
input_svd_data[:,0]
# Out:
# array([0.12491455, 0.11487509, 0.14972207, ..., 0.09497781, 0.14869694,
#        0.09084749])

# %%
# Pick r = 2 for NMF based on results from Part 3 (highest scores)
r = 2
input_nmf_data = NMF(n_components=r).fit_transform(X_train_tfidf)
predict_nmf_data = init_kmeans.fit_predict(input_nmf_data)
nmf_centers = init_kmeans.cluster_centers_ # ndarray(n_clusters, n_features), cluster center coordinates
print(input_nmf_data.shape, predict_nmf_data.shape, nmf_centers.shape)
visualize_kmeans_clustering(input_nmf_data, predict_nmf_data, nmf_centers, 'KMeans clustering result using NMF (r = 2) for dimentionality reduction')
# Out:
# (7882, 2) (7882,) (2, 2)

# %% [markdown]
# ### 4b. Transformation

# %% [markdown]
# Try the transformation methods below to see whether they increase the clustering performance. Perform transformation on SVD-reduced data and NMF-reduced data, respectively. Still use the best r we have in previous parts.<br>
# - Scaling features s.t. each feature has unit variance, i.e., each column of the reduced-dimensional data matrix has unit variance (if we use the convention that rows correspond to documents).
# - Applying a logarithmic non-linear transformation to the data vectors for the case with NMF (non-negative features):
# f(x) = log(x + epsilon), 0<=epsilon<=1
# - Try combining the above transformations for the NMF case. <br>
#
# To sum up, try the SVD case w/ and w/o performing scaling (2 possibilities). Similarly, try different combinations of w/ and w/o performing scaling and non-linearity for the NMF case (4 possibilities).

# %% [markdown]
# #### Case 1: SVD case w/o performing scaling

# %%
# No scaling for SVD
#svd_data_scaled = scale(input_svd_data, axis=0, with_mean=False, with_std=False) 
# Pick r = 2 for SVD based on results from Part 3 (highest scores)
# input_svd_data = svd_reduced[:,:2]
predict_svd_labels = init_kmeans.fit_predict(input_svd_data)
print('SVD without scaling:')
print(contingency_matrix(conv_train_target, predict_svd_labels, eps=None, sparse=False))
print('Measure scores:')
print_measure_scores(conv_train_target, predict_svd_labels)
# Out:
# SVD without scaling:
# [[3726  177]
#  [ 520 3459]]
# Measure scores:
# Homogeneity score: 0.5814909307607379
# Completeness score: 0.58397751630097
# V-measure score: 0.5827315709032068
# Adjusted rand score: 0.6775208075943945
# Adjusted mutual info score: 0.5826932882925123

# %%
svd_centers = init_kmeans.fit(input_svd_data).cluster_centers_ # ndarray(n_clusters, n_features), cluster center coordinates
print(input_svd_data.shape, predict_svd_labels.shape, svd_centers.shape)
visualize_kmeans_clustering(input_svd_data, predict_svd_labels, svd_centers, 'Kmeans clustering result using SVD without scaling (r = 2) for dimentionality reduction')
# Out:
# (7882, 2) (7882,) (2, 2)

# %% [markdown]
# #### Case 2: SVD case with performing scaling

# %%
# Scaling features to have unit variance for SVD
svd_data_scaled = scale(input_svd_data, axis=0, with_mean=False, with_std=True) 
svd_scaled_labels = init_kmeans.fit_predict(svd_data_scaled)
print('SVD with scaling to unit variance:')
print(contingency_matrix(conv_train_target, svd_scaled_labels, eps=None, sparse=False))
print('Measure scores:')
print_measure_scores(conv_train_target, svd_scaled_labels)
# Out:
# SVD with scaling to unit variance:
# [[2145 1758]
#  [ 242 3737]]
# Measure scores:
# Homogeneity score: 0.2261523832114103
# Completeness score: 0.25559819328003436
# V-measure score: 0.2399753871631827
# Adjusted rand score: 0.2424785037639421
# Adjusted mutual info score: 0.23990154989901197

# %%
svd_scaled_centers = init_kmeans.fit(svd_data_scaled).cluster_centers_
print(svd_data_scaled.shape, svd_scaled_labels.shape, svd_scaled_centers.shape)
visualize_kmeans_clustering(svd_data_scaled, svd_scaled_labels, svd_scaled_centers, 'Kmeans clustering result using SVD with scaling (r = 2) for dimentionality reduction')
# Out:
# (7882, 2) (7882,) (2, 2)

# %% [markdown]
# #### Case 3: NMF w/o performing scaling

# %%
# NMF (non-negative features) without performance scaling
r = 2
input_nmf_data = NMF(n_components=r).fit_transform(X_train_tfidf)

nmf_predict = init_kmeans.fit_predict(input_nmf_data)

print('NMF w/o scaling')
print(contingency_matrix(conv_train_target, nmf_predict, eps=None, sparse=False))
print('Measure scores:')
print_measure_scores(conv_train_target, nmf_predict)
# Out:
# NMF w/o scaling
# [[3594  309]
#  [ 158 3821]]
# Measure scores:
# Homogeneity score: 0.6790483562300399
# Completeness score: 0.680131609210451
# V-measure score: 0.6795895510492934
# Adjusted rand score: 0.7770177788377391
# Adjusted mutual info score: 0.679560193985564

# %%
nmf_centers = init_kmeans.fit(input_nmf_data).cluster_centers_
visualize_kmeans_clustering(input_nmf_data, nmf_predict, nmf_centers, 'Kmeans clustering result using NMF without scaling (r = 2) for dimentionality reduction')

# %% [markdown]
# #### Case 4:  NMF w/ performing scaling

# %%
# NMF (non-negative features) with performance scaling
r = 2
input_nmf_data = NMF(n_components=r).fit_transform(X_train_tfidf) 

# Scaling the NMF data
input_nmf_data_scaled = scale(input_nmf_data, with_mean=False, with_std=True)

nmf_scaled_predict = init_kmeans.fit_predict(input_nmf_data_scaled)

print('NMF with scaling')
print(contingency_matrix(conv_train_target, nmf_scaled_predict, eps=None, sparse=False))
print('Measure scores:')
print_measure_scores(conv_train_target, nmf_scaled_predict)
# Out:
# NMF with scaling
# [[ 364 3539]
#  [3872  107]]
# Measure scores:
# Homogeneity score: 0.684387226603582
# Completeness score: 0.6871211383812941
# V-measure score: 0.6857514576553903
# Adjusted rand score: 0.7752292094559813
# Adjusted mutual info score: 0.6857226307192915

# %%
nmf_scaled_centers = init_kmeans.fit(input_nmf_data_scaled).cluster_centers_
visualize_kmeans_clustering(input_nmf_data_scaled, nmf_scaled_predict, nmf_scaled_centers, 'Kmeans clustering result using NMF with scaling (r = 2) for dimentionality reduction')

# %% [markdown]
# #### Case 5: Logarithmic transformed NMF w/o performing scaling

# %%
# Logarithmic transformation to the data vectors for the case with NMF (non-negative features)
r = 2
input_nmf_data = NMF(n_components=r).fit_transform(X_train_tfidf)

epsilon = 5e-4
nmf_log = np.log(input_nmf_data + epsilon)

nmf_log_predict = init_kmeans.fit_predict(nmf_log)

print('NMF after logarithm transformation w/o scaling')
print(contingency_matrix(conv_train_target, nmf_log_predict, eps=None, sparse=False))
print('Measure scores:')
print_measure_scores(conv_train_target, nmf_log_predict)
# Out:
# NMF after logarithm transformation w/o scaling
# [[ 162 3741]
#  [3757  222]]
# Measure scores:
# Homogeneity score: 0.7198948500602957
# Completeness score: 0.719862751118043
# V-measure score: 0.7198788002313514
# Adjusted rand score: 0.8145960872788734
# Adjusted mutual info score: 0.7198531556291674

# %%
nmf_log_centers = init_kmeans.fit(nmf_log).cluster_centers_
visualize_kmeans_clustering(nmf_log, nmf_log_predict, nmf_log_centers, 'Kmeans clustering result using logarithmic NMF without scaling (r = 2) for dimentionality reduction')

# %% [markdown]
# #### Case 6: Logrithmic transformed NMF w/ performing scaling

# %%
# Logarithmic transformation to the data vectors for the case with NMF (non-negative features) with scaling
r = 2
# input_nmf_data = NMF(n_components=r).fit_transform(X_train_tfidf)

# Scaling the NMF data
nmf_data_scaled = scale(input_nmf_data, with_mean=False, with_std=True) 

# Apply a logarithmic non-linear transformation to the data vectors:
epsilon = 0.04
# Input data vectors:
nmf_scaled_log = np.log(nmf_data_scaled + epsilon)
print('NMF scaled log.shape:', nmf_scaled_log.shape)

#Predicted labels:
nmf_scaled_log_predict = init_kmeans.fit_predict(nmf_scaled_log)

print('NMF after logarithm transformation w/ scaling')
print(contingency_matrix(conv_train_target, nmf_scaled_log_predict, eps=None, sparse=False))
print('5 Measure scores:')
print_measure_scores(conv_train_target, nmf_scaled_log_predict)
# Out:
# NMF scaled log.shape: (7882, 2)
# NMF after logarithm transformation w/ scaling
# [[3738  165]
#  [ 217 3762]]
# 5 Measure scores:
# Homogeneity score: 0.7207893931774468
# Completeness score: 0.7207476133884125
# V-measure score: 0.7207685026774819
# Adjusted rand score: 0.815512535884567
# Adjusted mutual info score: 0.7207429396970972

# %%
nmf_scaled_log_centers = init_kmeans.fit(nmf_scaled_log).cluster_centers_
visualize_kmeans_clustering(nmf_scaled_log, nmf_log_predict, nmf_scaled_log_centers, 'Kmeans clustering result using logarithmic NMF with scaling (r = 2) for dimentionality reduction')
